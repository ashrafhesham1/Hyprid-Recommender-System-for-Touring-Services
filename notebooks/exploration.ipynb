# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
rest_row = pd.read_json(r'.\Row data\resturants.json')
hot_row = pd.read_json(r'.\Row data\hotels.json')
attr_row = pd.read_json(r'.\Row data\attractions.json')

# %% [markdown]
# ## Data Exploration

# %%
rest_row.info()
rest_row.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7015 entries, 0 to 7014
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   7015 non-null   int64
#  1   type                 7015 non-null   object
#  2   name                 7015 non-null   object
#  3   image                2343 non-null   object
#  4   awards               7015 non-null   object
#  5   rankingPosition      3448 non-null   float64
#  6   priceLevel           7015 non-null   object
#  7   category             3448 non-null   object
#  8   rating               3439 non-null   float64
#  9   isClosed             7015 non-null   bool
#  10  isLongClosed         7015 non-null   bool
#  11  phone                2595 non-null   object
#  12  address              7015 non-null   object
#  13  email                952 non-null    object
#  14  cuisine              7015 non-null   object
# ...

# %%
rest_row_single = rest_row.drop(['dietaryRestrictions','hours','awards','cuisine','reviews','reviewTags','mealTypes'],axis = 1)

# %%
rest_row_single.head()
# Out:
#          id        type                                     name  \
# 0   7313924  RESTAURANT                       Corallo Restaurant
# 1   3752925  RESTAURANT                              Makai Tukai
# 2   7233925  RESTAURANT  Sofra Middle Eastern Cuisine - Hurghada
# 3  21276749  RESTAURANT                         Amaya Restaurant
# 4   3752928  RESTAURANT                                    Sofra
#
#                                                image  rankingPosition  \
# 0  https://media-cdn.tripadvisor.com/media/photo-...              8.0
# 1  https://media-cdn.tripadvisor.com/media/photo-...              6.0
# 2  https://media-cdn.tripadvisor.com/media/photo-...              2.0
# 3  https://media-cdn.tripadvisor.com/media/photo-...              7.0
# 4  https://media-cdn.tripadvisor.com/media/photo-...              3.0
#
#   priceLevel    category  rating  isClosed  isLongClosed  ...  \
# 0   $$ - $$$  restaurant     5.0     False         False  ...
# ...

# %%
rest_row_single.nunique(axis = 0)
# Out:
# id                    7015
# type                     1
# name                  5545
# image                 2343
# rankingPosition       1911
# priceLevel               4
# category                 1
# rating                   9
# isClosed                 1
# isLongClosed             1
# phone                 2291
# address               6324
# email                  781
# latitude              4727
# longitude             4728
# webUrl                7015
# website               1610
# rankingDenominator      13
# rankingString         3448
# numberOfReviews        351
# reviewsCount            99
# dtype: int64

# %%
rest_row_single['numberOfReviews'].describe()
# Out:
# count    7015.000000
# mean       26.693942
# std       138.621490
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         5.000000
# max      3526.000000
# Name: numberOfReviews, dtype: float64

# %%
res_reviews = {}
for i,row in rest_row.iterrows():
    res_reviews[i] = row['reviews']

# %%
res_reviews[0][0]
# Out:
# {'id': '869681488',
#  'lang': 'en',
#  'location_id': '7313924',
#  'published_date': '2022-11-25T09:51:47-05:00',
#  'published_platform': 'Mobile',
#  'rating': '5',
#  'type': 'review',
#  'helpful_votes': '0',
#  'url': 'https://www.tripadvisor.com/ShowUserReviews-g297549-d7313924-r869681488-Corallo_Restaurant-Hurghada_Red_Sea_and_Sinai.html#review869681488',
#  'travel_date': '2022-11',
#  'text': 'Thank you guys it was amazing. Very good food and bouillabaisse. Very helpful and informative waithers. Enjoy.',
#  'user': {'user_id': '54BBB2FD2E0C54C8407A1C4DECDEE647',
#   'type': 'user',
#   'first_name': None,
#   'last_initial': None,
#   'name': None,
#   'reviewer_type': None,
#   'contributions': {'reviews': '1',
#    'review_city_count': '0',
#    'restaurant_reviews': '1',
#    'hotel_reviews': '0',
#    'attraction_reviews': '0',
#    'helpful_votes': '0',
#    'photos_count': '0',
#    'badges_count': '0'},
#   'member_id': '0',
#   'username': 'Savoldelli58',
# ...

# %%
rest_row['reviews'].iter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-9ee5b8008126> in <module>
# ----> 1 rest_row['reviews'].iter
#
# ~\anaconda3\envs\trav\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'iter'

# %%
hot_row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1243 non-null   int64
#  1   type                   1243 non-null   object
#  2   name                   1243 non-null   object
#  3   image                  995 non-null    object
#  4   awards                 1243 non-null   object
#  5   priceLevel             1243 non-null   object
#  6   hotelClass             1243 non-null   float64
#  7   address                1243 non-null   object
#  8   amenities              1243 non-null   object
#  9   prices                 1243 non-null   object
#  10  latitude               1089 non-null   float64
#  11  longitude              1089 non-null   float64
#  12  webUrl                 1243 non-null   object
#  13  numberOfReviews        1243 non-null   int64
# ...

# %%
hot_row.describe()
# Out:
#                  id   hotelClass     latitude    longitude  numberOfReviews  \
# count  1.243000e+03  1243.000000  1089.000000  1089.000000      1243.000000
# mean   9.551592e+06     2.012872    28.146719    32.723238       815.014481
# std    9.875891e+06     2.059754     1.886203     2.038235      1694.111716
# min    2.991060e+05     0.000000    24.012660    25.436210         0.000000
# 25%    6.530735e+05     0.000000    27.104520    31.262564         1.000000
# 50%    3.177173e+06     2.000000    27.916800    33.821037        37.000000
# 75%    2.117696e+07     4.000000    30.044483    34.320004       794.500000
# max    2.516955e+07     5.000000    31.393322    35.086834     13686.000000
#
#        reviewsCount  rankingPosition      rating  rankingDenominator
# count   1243.000000       989.000000  990.000000          989.000000
# mean      88.152856        77.879676    3.837374          169.945399
# std      107.798878        74.223079    0.923142          109.777900
# ...

# %%
hot_row['priceRange'].describe()
# Out:
# count           922
# unique          850
# top       $31 - $39
# freq              4
# Name: priceRange, dtype: object

# %%
attr_row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 57 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   type                                       2264 non-null   object
#  1   image                                      2139 non-null   object
#  2   location_id                                2264 non-null   int64
#  3   name                                       2264 non-null   object
#  4   latitude                                   1255 non-null   float64
#  5   longitude                                  1255 non-null   float64
#  6   num_reviews                                2264 non-null   int64
#  7   timezone                                   2264 non-null   object
#  8   location_string                            2264 non-null   object
#  9   photo                                      2139 non-null   object
# ...

# %%
attr_row['fee']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2259    NaN
# 2260    NaN
# 2261    NaN
# 2262    NaN
# 2263    NaN
# Name: fee, Length: 2264, dtype: object
